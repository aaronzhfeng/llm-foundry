# %% [markdown]
# # Training Time Analysis
#
# This notebook computes the actual total training time for each model by summing up the time_ms for each iteration from the JSON logs.
#
# **Models:**
# - Qwen3 1.8B Optimal (24L-16H-2048D)
# - GPT-2 1.29B (18L-18H-2304D)
# - LLaMA 3 2.2B Chinchilla (30L-16H-2048D)
# - LLaMA 2 1.36B (18L-18H-2304D)
